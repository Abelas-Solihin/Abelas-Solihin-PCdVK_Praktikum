# %% [markdown]
# <a href="https://colab.research.google.com/github/Abelas-Solihin/Abelas-Solihin-PCdVK_Praktikum/blob/main/Pertemuan_2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
